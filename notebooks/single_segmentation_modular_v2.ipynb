# %% [markdown]
# # Modular Single Segmentation Notebook

# %%
import yaml
from benchmark_models import build_adapters_from_config

with open('single_segmentation_config_modular.yaml', 'r') as f:
    cfg = yaml.safe_load(f)

print(cfg)
